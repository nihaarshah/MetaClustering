# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from MetaLSTM import MetaLSTM
from generate import generate_dataset, generate_nonlinear_dataset

# %%
data, labels = generate_dataset(100, 2, 4, 10, 1, 2)
plt.scatter(x=data[:, 0], y=data[:, 1], c=labels)
# Out:
# [array([[ 1.21753548e-01, -7.79568954e-18],
#        [-7.79568954e-18,  1.21753548e-01]]), array([[1.48208815e-01, 1.55211182e-17],
#        [1.55211182e-17, 1.48208815e-01]]), array([[4.06853429e-01, 3.37322824e-17],
#        [3.37322824e-17, 4.06853429e-01]]), array([[ 7.52199639e-01, -5.31313293e-17],
#        [-5.31313293e-17,  7.52199639e-01]])]

# %%
data, labels = generate_nonlinear_dataset(n=25, d=2, k=4,                                               rng=10,
                                              alpha=10,                                                      beta=5,
                                               a_nl=10,                                                      b_nl=2
                                              )

plt.scatter(x=data[:, 0], y=data[:, 1], c=labels)
# Out:
# [array([[ 6.73491125e-03, -8.60602754e-20],
#        [-8.60602754e-20,  6.73491125e-03]]), array([[ 8.01508897e-03, -1.82898801e-19],
#        [-1.82898801e-19,  8.01508897e-03]]), array([[5.81843390e-03, 7.15302929e-19],
#        [7.15302929e-19, 5.81843390e-03]]), array([[9.48258112e-03, 9.93606358e-20],
#        [9.93606358e-20, 9.48258112e-03]])]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Axes3D.plot(xs, ys, *args, **kwargs)
